# %%
from utils import FileDataset, AnomalyDataset, cache
from net import SpatialEncoder
from pathlib import Path
import os
import torch
import torch.nn as nn
import wandb
import tqdm
import gc
import numpy as np
import scipy.io as sio
import pandas as pd
import numpy as np
import torch
from pathlib import Path
import os
import matplotlib.pyplot as plt
import tqdm
import torch.nn as nn
from torch.utils.data import Dataset
from collections import namedtuple
import tqdm
from torchvision.transforms import Resize, Compose, ToPILImage, ToTensor
from PIL import Image
import torch.nn.functional as F
from conv_lstm import ConvLSTM
from matplotlib import cm
from disk import getCache

# %%
wandb.init(project='anomaly', entity='coinitialized')
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: damiankucharski (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.30<br/>
#                 Syncing run <strong style="color:#cdcd00">daily-silence-22</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/coinitialized/anomaly" target="_blank">https://wandb.ai/coinitialized/anomaly</a><br/>
#                 Run page: <a href="https://wandb.ai/coinitialized/anomaly/runs/1h9s6lo5" target="_blank">https://wandb.ai/coinitialized/anomaly/runs/1h9s6lo5</a><br/>
#                 Run data is saved locally in <code>c:\Users\cdami\Documents\Python Scripts\Spatiotemporal-Autoencoder-Anomaly-Detection\wandb\run-20210524_190921-1h9s6lo5</code><br/><br/>
# <h1>Run(1h9s6lo5)</h1><iframe src="https://wandb.ai/coinitialized/anomaly/runs/1h9s6lo5" style="border:none;width:100%;height:400px"></iframe>

# %%
train_path = Path('Avenue Dataset/training_vol')
test_path = Path('Avenue Dataset/testing_vol')

# %%
device = torch.device('cuda')
model = SpatialEncoder()
model = model.to(device)

# %%
optimizer = torch.optim.Adam(model.parameters())
loss = nn.MSELoss()
epochs = 50

# %%
set_train = FileDataset(train_path, test_path, train=True) 
set_test = FileDataset(train_path, test_path, train=False)

train_data_loader = torch.utils.data.DataLoader(set_train, batch_size=1, shuffle=True)
test_data_loader = torch.utils.data.DataLoader(set_test, batch_size=1, shuffle=True)

# %%
losses_train = []
losses_test = []

# %%
for i in tqdm.tqdm(range(epochs)):

    print('train')
    batch_loss_train = []
    model.train()

    batch_loss_train = []
    for X in tqdm.tqdm(train_data_loader):


        print(type(X))
        print(X.size())

        set_train = AnomalyDataset(X[0], train=True) 
        print(len(set_train))
        train_loader = torch.utils.data.DataLoader(set_train, batch_size=12, shuffle=True)
        for X_batch in tqdm.tqdm(train_loader):
            optimizer.zero_grad()
            X_batch = X_batch.to(device)
            predictions = model(X_batch)
            loss_val = loss(predictions, X_batch)
            batch_loss_train.append(loss_val.item())
            loss_val.backward()
            optimizer.step()
            del X_batch
            gc.collect()
        del X
        gc.collect()

    losses_train.append(np.mean(batch_loss_train))

    print('test')
    batch_loss_test = []
    for X in tqdm.tqdm(test_data_loader):
        
        set_test = AnomalyDataset(X[0], train=True) 
        test_loader = torch.utils.data.DataLoader(set_test, batch_size=12, shuffle=True)

        model.eval()
        batch_loss_test = []
        for X_batch in tqdm.tqdm(test_loader):
            X_batch = X_batch.to(device)
            predictions = model(X_batch)
            loss_val = loss(predictions, X_batch)
            batch_loss_test.append(loss_val.item())
            del X_batch
            gc.collect()
        del X
        gc.collect()
    
    losses_test.append(np.mean(batch_loss_test))

    output_image = predictions[:1,...]
    output_image = output_image.squeeze()
    one_frame = output_image[0,...]
    one_frame_numpy = one_frame.cpu().detach().numpy()
    im = Image.fromarray(np.uint8(cm.gray(one_frame_numpy)*255))

    wandb.log({"loss_train": losses_train[-1],"loss_test": losses_test[-1], "epoch": i,
            "inputs": wandb.Image(im),
            })


    PATH = f"checkpoints/{i}_model.pt"

    torch.save({
            'epoch': i,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss_train': losses_train[-1],
            'loss_test' : losses_test[-1]
            }, PATH)
    if i > 5:
        if losses_test[i-5] - losses_test[i-1] < 0.00025 or losses_test[i-1] < losses_test[i]:
            break
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]train
# Generating strides for Avenue Dataset\training_vol\vol16.mat
# Generating strides for Avenue Dataset\training_vol\vol16.mat
# Generating strides for Avenue Dataset\training_vol\vol16.mat
#
#
#   0%|          | 0/29 [00:00<?, ?it/s]<class 'torch.Tensor'>
# torch.Size([1, 429, 1, 10, 227, 227])
# 343
# C:\Users\cdami\Anaconda3\lib\site-packages\torch\nn\functional.py:1628: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# C:\Users\cdami\Anaconda3\lib\site-packages\torch\nn\functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
#
#
#   3%|▎         | 1/29 [00:00<00:18,  1.52it/s]
#
#   7%|▋         | 2/29 [00:00<00:14,  1.80it/s]
#
#  10%|█         | 3/29 [00:01<00:15,  1.65it/s]
#
#  14%|█▍        | 4/29 [00:02<00:16,  1.55it/s]
#
#  17%|█▋        | 5/29 [00:03<00:15,  1.51it/s]
#
#  21%|██        | 6/29 [00:03<00:15,  1.49it/s]
#
#  24%|██▍       | 7/29 [00:04<00:14,  1.48it/s]
#
#  28%|██▊       | 8/29 [00:05<00:14,  1.48it/s]
#
#  31%|███       | 9/29 [00:05<00:13,  1.47it/s]
#
#  34%|███▍      | 10/29 [00:06<00:13,  1.45it/s]
#
#  38%|███▊      | 11/29 [00:07<00:12,  1.46it/s]
#
#  41%|████▏     | 12/29 [00:07<00:11,  1.44it/s]
#
#  45%|████▍     | 13/29 [00:08<00:11,  1.45it/s]
#
#  48%|████▊     | 14/29 [00:09<00:10,  1.45it/s]
#
#  52%|█████▏    | 15/29 [00:10<00:09,  1.46it/s]
#
#  55%|█████▌    | 16/29 [00:10<00:08,  1.47it/s]
#
#  59%|█████▊    | 17/29 [00:11<00:08,  1.47it/s]
#
#  62%|██████▏   | 18/29 [00:12<00:07,  1.47it/s]
#
#  66%|██████▌   | 19/29 [00:12<00:06,  1.49it/s]
#
#  69%|██████▉   | 20/29 [00:13<00:06,  1.48it/s]
#
#  72%|███████▏  | 21/29 [00:14<00:05,  1.50it/s]
#
#  76%|███████▌  | 22/29 [00:14<00:04,  1.51it/s]
#
#  79%|███████▉  | 23/29 [00:15<00:04,  1.50it/s]
#
#  83%|████████▎ | 24/29 [00:16<00:03,  1.50it/s]
#
#  86%|████████▌ | 25/29 [00:16<00:02,  1.49it/s]
#
#  90%|████████▉ | 26/29 [00:17<00:02,  1.49it/s]
#
#  93%|█████████▎| 27/29 [00:18<00:01,  1.49it/s]
#
#  97%|█████████▋| 28/29 [00:18<00:00,  1.49it/s]
#
# 100%|██████████| 29/29 [00:19<00:00,  1.50it/s]
#
#  10%|█         | 1/10 [00:23<03:27, 23.10s/it]Generating strides for Avenue Dataset\training_vol\vol14.mat
# Generating strides for Avenue Dataset\training_vol\vol14.mat
# Generating strides for Avenue Dataset\training_vol\vol14.mat
#
#
#   0%|          | 0/62 [00:00<?, ?it/s]<class 'torch.Tensor'>
# torch.Size([1, 917, 1, 10, 227, 227])
# 733
#
#
#   2%|▏         | 1/62 [00:00<00:14,  4.20it/s]
#
#   3%|▎         | 2/62 [00:00<00:22,  2.66it/s]
#
#   5%|▍         | 3/62 [00:01<00:27,  2.14it/s]
#
#   6%|▋         | 4/62 [00:02<00:30,  1.88it/s]
#
#   8%|▊         | 5/62 [00:02<00:32,  1.74it/s]
#
#  10%|▉         | 6/62 [00:03<00:33,  1.65it/s]
#
#  11%|█▏        | 7/62 [00:04<00:34,  1.59it/s]
#
#  13%|█▎        | 8/62 [00:05<00:34,  1.55it/s]
#
#  15%|█▍        | 9/62 [00:05<00:34,  1.52it/s]
#
#  16%|█▌        | 10/62 [00:06<00:34,  1.50it/s]
#
#  18%|█▊        | 11/62 [00:07<00:34,  1.48it/s]
#
#  19%|█▉        | 12/62 [00:07<00:33,  1.48it/s]
#
#  21%|██        | 13/62 [00:08<00:33,  1.47it/s]
#
#  23%|██▎       | 14/62 [00:09<00:32,  1.48it/s]
#
#  24%|██▍       | 15/62 [00:09<00:31,  1.48it/s]
#
#  26%|██▌       | 16/62 [00:10<00:31,  1.48it/s]
#
#  27%|██▋       | 17/62 [00:11<00:30,  1.48it/s]
#
#  29%|██▉       | 18/62 [00:11<00:29,  1.48it/s]
#
#  31%|███       | 19/62 [00:12<00:29,  1.48it/s]
#
#  32%|███▏      | 20/62 [00:13<00:28,  1.49it/s]
#
#  34%|███▍      | 21/62 [00:13<00:27,  1.49it/s]
#
#  35%|███▌      | 22/62 [00:14<00:26,  1.48it/s]
#
#  37%|███▋      | 23/62 [00:15<00:26,  1.48it/s]
#
#  39%|███▊      | 24/62 [00:15<00:25,  1.46it/s]
#
#  40%|████      | 25/62 [00:16<00:25,  1.46it/s]
#
#  42%|████▏     | 26/62 [00:17<00:24,  1.47it/s]
#
#  44%|████▎     | 27/62 [00:17<00:24,  1.45it/s]
#
#  45%|████▌     | 28/62 [00:18<00:23,  1.47it/s]
#
#  47%|████▋     | 29/62 [00:19<00:22,  1.47it/s]
#
#  48%|████▊     | 30/62 [00:19<00:21,  1.46it/s]
#
#  50%|█████     | 31/62 [00:20<00:21,  1.48it/s]
#
#  52%|█████▏    | 32/62 [00:21<00:20,  1.48it/s]
#
#  53%|█████▎    | 33/62 [00:22<00:19,  1.47it/s]
#
#  55%|█████▍    | 34/62 [00:22<00:19,  1.46it/s]
#
#  56%|█████▋    | 35/62 [00:23<00:18,  1.46it/s]
#
#  58%|█████▊    | 36/62 [00:24<00:18,  1.44it/s]
#
#  60%|█████▉    | 37/62 [00:24<00:17,  1.43it/s]
#
#  61%|██████▏   | 38/62 [00:25<00:16,  1.43it/s]
#
#  63%|██████▎   | 39/62 [00:26<00:16,  1.42it/s]
#
#  65%|██████▍   | 40/62 [00:26<00:15,  1.41it/s]
#
#  66%|██████▌   | 41/62 [00:27<00:14,  1.41it/s]
#
#  68%|██████▊   | 42/62 [00:28<00:14,  1.42it/s]
#
#  69%|██████▉   | 43/62 [00:29<00:13,  1.41it/s]
#
#  71%|███████   | 44/62 [00:29<00:12,  1.41it/s]
#
#  73%|███████▎  | 45/62 [00:30<00:12,  1.40it/s]
#
#  74%|███████▍  | 46/62 [00:31<00:11,  1.40it/s]
#
#  76%|███████▌  | 47/62 [00:31<00:10,  1.39it/s]
#
#  77%|███████▋  | 48/62 [00:32<00:10,  1.40it/s]
#
#  79%|███████▉  | 49/62 [00:33<00:09,  1.39it/s]
#
#  81%|████████  | 50/62 [00:34<00:08,  1.39it/s]
#
#  82%|████████▏ | 51/62 [00:34<00:07,  1.40it/s]
#
#  84%|████████▍ | 52/62 [00:35<00:07,  1.39it/s]
#
#  85%|████████▌ | 53/62 [00:36<00:06,  1.40it/s]
#
#  87%|████████▋ | 54/62 [00:36<00:05,  1.39it/s]
#
#  89%|████████▊ | 55/62 [00:37<00:05,  1.35it/s]
#
#  90%|█████████ | 56/62 [00:38<00:04,  1.36it/s]
#
#  92%|█████████▏| 57/62 [00:39<00:03,  1.36it/s]
#
#  94%|█████████▎| 58/62 [00:39<00:02,  1.36it/s]
#
#  95%|█████████▌| 59/62 [00:40<00:02,  1.38it/s]
#
#  97%|█████████▋| 60/62 [00:41<00:01,  1.38it/s]
#
#  98%|█████████▊| 61/62 [00:42<00:00,  1.37it/s]
#
# 100%|██████████| 62/62 [00:42<00:00,  1.45it/s]
#
#  20%|██        | 2/10 [01:13<04:10, 31.33s/it]Generating strides for Avenue Dataset\training_vol\vol10.mat
# Generating strides for Avenue Dataset\training_vol\vol10.mat
# Generating strides for Avenue Dataset\training_vol\vol10.mat
#
#
#   0%|          | 0/149 [00:00<?, ?it/s]<class 'torch.Tensor'>
# torch.Size([1, 2225, 1, 10, 227, 227])
# 1780
#
#
#   1%|          | 1/149 [00:01<03:02,  1.23s/it]
#
#   1%|▏         | 2/149 [00:01<02:17,  1.07it/s]
#
#   2%|▏         | 3/149 [00:02<02:05,  1.17it/s]
#
#   3%|▎         | 4/149 [00:02<01:56,  1.24it/s]
#
#   3%|▎         | 5/149 [00:03<01:49,  1.31it/s]
#
#   4%|▍         | 6/149 [00:04<01:45,  1.36it/s]
#
#   5%|▍         | 7/149 [00:04<01:42,  1.38it/s]
#
#   5%|▌         | 8/149 [00:05<01:40,  1.41it/s]
#
#   6%|▌         | 9/149 [00:06<01:38,  1.43it/s]
#
#   7%|▋         | 10/149 [00:06<01:35,  1.45it/s]
#
#   7%|▋         | 11/149 [00:07<01:35,  1.45it/s]
#
#   8%|▊         | 12/149 [00:08<01:33,  1.46it/s]
#
#   9%|▊         | 13/149 [00:08<01:32,  1.47it/s]
#
#   9%|▉         | 14/149 [00:09<01:32,  1.47it/s]
#
#  10%|█         | 15/149 [00:10<01:31,  1.47it/s]
#
#  11%|█         | 16/149 [00:10<01:30,  1.47it/s]
#
#  11%|█▏        | 17/149 [00:11<01:29,  1.48it/s]
#
#  12%|█▏        | 18/149 [00:12<01:29,  1.47it/s]
#
#  13%|█▎        | 19/149 [00:12<01:28,  1.48it/s]
#
#  13%|█▎        | 20/149 [00:13<01:28,  1.46it/s]
#
#  14%|█▍        | 21/149 [00:14<01:27,  1.47it/s]
#
#  15%|█▍        | 22/149 [00:15<01:26,  1.47it/s]
#
#  15%|█▌        | 23/149 [00:15<01:25,  1.47it/s]
#
#  16%|█▌        | 24/149 [00:16<01:25,  1.46it/s]
#
#  17%|█▋        | 25/149 [00:17<01:24,  1.47it/s]
#
#  17%|█▋        | 26/149 [00:17<01:24,  1.46it/s]
#
#  18%|█▊        | 27/149 [00:18<01:23,  1.47it/s]
#
#  19%|█▉        | 28/149 [00:19<01:22,  1.46it/s]
#  20%|██        | 2/10 [02:00<08:00, 60.09s/it]
#   0%|          | 0/50 [02:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-e582e71e3afa> in <module>
#      15         print(len(set_train))
#      16         train_loader = torch.utils.data.DataLoader(set_train, batch_size=12, shuffle=True)
# ---> 17         for X_batch in tqdm.tqdm(train_loader):
#      18             optimizer.zero_grad()
#      19             X_batch = X_batch.to(device)
#
# ~\Anaconda3\lib\site-packages\tqdm\std.py in __iter__(self)
#    1182
#    1183                         self.n = n
# -> 1184                         self.refresh(lock_args=self.lock_args)
#    1185
#    1186                         # If no `miniters` was specified, adjust automatically
#
# ~\Anaconda3\lib\site-packages\tqdm\std.py in refresh(self, nolock, lock_args)
#    1378             else:
#    1379                 self._lock.acquire()
# -> 1380         self.display()
#    1381         if not nolock:
#    1382             self._lock.release()
#
# ~\Anaconda3\lib\site-packages\tqdm\std.py in display(self, msg, pos)
#    1511
#    1512         if pos:
# -> 1513             self.moveto(pos)
#    1514         self.sp(self.__repr__() if msg is None else msg)
#    1515         if pos:
#
# ~\Anaconda3\lib\site-packages\tqdm\std.py in moveto(self, n)
#    1466     def moveto(self, n):
#    1467         # TODO: private method
# -> 1468         self.fp.write(_unicode('\n' * n + _term_move_up() * -n))
#    1469         self.fp.flush()
#    1470
#
# ~\Anaconda3\lib\site-packages\tqdm\utils.py in inner(*args, **kwargs)
#     221         def inner(*args, **kwargs):
#     222             try:
# --> 223                 return func(*args, **kwargs)
#     224             except (IOError, OSError) as e:
#     225                 if e.errno != 5:
#
# ~\Anaconda3\lib\site-packages\wandb\sdk\lib\redirect.py in write(data)
#     476
#     477         def write(data):
# --> 478             self._old_write(data)
#     479             if isinstance(data, bytes):
#     480                 try:
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\Anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     414                                  copy_threshold=self.copy_threshold)
#     415             data.group = group
# --> 416         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     417
#     418     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
